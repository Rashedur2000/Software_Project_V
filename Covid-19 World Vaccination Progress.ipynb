# %%
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv('country_vaccinations.csv')

# %%
dataset
# Out:
#           Country ISO Code      Date  Total Vaccinations  1st Dose  2nd Dose  \
# 0     Afghanistan      AFG  22-02-21                 0.0       0.0       NaN
# 1     Afghanistan      AFG  23-02-21                 NaN       NaN       NaN
# 2     Afghanistan      AFG  24-02-21                 NaN       NaN       NaN
# 3     Afghanistan      AFG  25-02-21                 NaN       NaN       NaN
# 4     Afghanistan      AFG  26-02-21                 NaN       NaN       NaN
# ...           ...      ...       ...                 ...       ...       ...
# 9571     Zimbabwe      ZWE  29-03-21             81610.0   69751.0   11859.0
# 9572     Zimbabwe      ZWE  30-03-21             85866.0   72944.0   12922.0
# 9573     Zimbabwe      ZWE  31-03-21             91880.0   76995.0   14885.0
# 9574     Zimbabwe      ZWE  01-04-21            105307.0   87791.0   17516.0
# 9575     Zimbabwe      ZWE  02-04-21            124753.0  103815.0   20938.0
#
# ...

# %%
dataset.head()
# Out:
#        Country ISO Code      Date  Total Vaccinations  1st Dose  2nd Dose  \
# 0  Afghanistan      AFG  22-02-21                 0.0       0.0       NaN
# 1  Afghanistan      AFG  23-02-21                 NaN       NaN       NaN
# 2  Afghanistan      AFG  24-02-21                 NaN       NaN       NaN
# 3  Afghanistan      AFG  25-02-21                 NaN       NaN       NaN
# 4  Afghanistan      AFG  26-02-21                 NaN       NaN       NaN
#
#    Daily Vaccinations            Vaccines                Source Name
# 0                 NaN  Oxford/AstraZeneca  Government of Afghanistan
# 1              1367.0  Oxford/AstraZeneca  Government of Afghanistan
# 2              1367.0  Oxford/AstraZeneca  Government of Afghanistan
# 3              1367.0  Oxford/AstraZeneca  Government of Afghanistan
# 4              1367.0  Oxford/AstraZeneca  Government of Afghanistan

# %%
dataset.tail()
# Out:
#        Country ISO Code      Date  Total Vaccinations  1st Dose  2nd Dose  \
# 9571  Zimbabwe      ZWE  29-03-21             81610.0   69751.0   11859.0
# 9572  Zimbabwe      ZWE  30-03-21             85866.0   72944.0   12922.0
# 9573  Zimbabwe      ZWE  31-03-21             91880.0   76995.0   14885.0
# 9574  Zimbabwe      ZWE  01-04-21            105307.0   87791.0   17516.0
# 9575  Zimbabwe      ZWE  02-04-21            124753.0  103815.0   20938.0
#
#       Daily Vaccinations           Vaccines         Source Name
# 9571              5434.0  Sinopharm/Beijing  Ministry of Health
# 9572              5810.0  Sinopharm/Beijing  Ministry of Health
# 9573              5712.0  Sinopharm/Beijing  Ministry of Health
# 9574              6617.0  Sinopharm/Beijing  Ministry of Health
# 9575              8156.0  Sinopharm/Beijing  Ministry of Health

# %%
dataset.dtypes
# Out:
# Country                object
# ISO Code               object
# Date                   object
# Total Vaccinations    float64
# 1st Dose              float64
# 2nd Dose              float64
# Daily Vaccinations    float64
# Vaccines               object
# Source Name            object
# dtype: object

# %%
dataset.columns
# Out:
# Index(['Country', 'ISO Code', 'Date', 'Total Vaccinations', '1st Dose',
#        '2nd Dose', 'Daily Vaccinations', 'Vaccines', 'Source Name'],
#       dtype='object')

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=9576, step=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             9576 non-null   object
#  1   ISO Code            9576 non-null   object
#  2   Date                9576 non-null   object
#  3   Total Vaccinations  5772 non-null   float64
#  4   1st Dose            5167 non-null   float64
#  5   2nd Dose            3608 non-null   float64
#  6   Daily Vaccinations  9393 non-null   float64
#  7   Vaccines            9576 non-null   object
#  8   Source Name         9576 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 673.4+ KB

# %%
dataset.mean()
# Out:
# Total Vaccinations    3.223423e+06
# 1st Dose              2.406510e+06
# 2nd Dose              1.076638e+06
# Daily Vaccinations    6.705204e+04
# dtype: float64

# %%
dataset.groupby(["Country"]).mean()
# Out:
#              Total Vaccinations       1st Dose       2nd Dose  \
# Country
# Afghanistan        20733.333333   20733.333333            NaN
# Albania            33633.294118     906.312500     463.200000
# Algeria            25010.000000            NaN            NaN
# Andorra             3432.545455    2471.444444    1233.666667
# Angola             54588.200000   54588.200000            NaN
# ...                         ...            ...            ...
# Uruguay           296817.944444  288594.166667   37007.000000
# Venezuela           6643.500000    6643.500000            NaN
# Vietnam            28758.071429   28758.071429            NaN
# Wales             888290.435294  763368.505882  129492.243902
# Zimbabwe           41879.146341   39166.756098    9267.333333
#
#              Daily Vaccinations
# Country
# Afghanistan         2250.409091
# Albania             1442.853659
# Algeria             3289.047619
# Andorra              151.339623
# Angola              3839.178571
# ...

# %%
dataset.groupby(["Date"]).mean()
# Out:
#           Total Vaccinations      1st Dose      2nd Dose  Daily Vaccinations
# Date
# 01-01-21        9.369235e+04  9.904307e+04  8.470000e+02        21809.325581
# 01-02-21        1.682408e+06  1.527581e+06  3.191704e+05        58734.554217
# 01-03-21        2.714726e+06  2.148854e+06  1.019913e+06        51058.687500
# 01-04-21        7.028266e+06  4.497681e+06  2.105445e+06       159976.222222
# 02-01-21        3.805054e+05  3.964296e+05  1.062000e+03        23641.139535
# ...                      ...           ...           ...                 ...
# 30-03-21        6.531086e+06  4.098844e+06  1.853116e+06       129924.460870
# 30-12-20        1.520467e+05  1.674157e+05  7.300000e+02        22554.621622
# 31-01-21        2.211961e+06  1.552760e+06  2.993086e+05        56683.134146
# 31-03-21        6.141965e+06  3.991390e+06  1.931438e+06       138024.765766
# 31-12-20        2.533009e+05  8.459971e+04  8.470000e+02        21370.707317
#
# [112 rows x 4 columns]

# %%
dataset.groupby(["Vaccines"]).mean()
# Out:
#                                                     Total Vaccinations  \
# Vaccines
# Covaxin, Oxford/AstraZeneca                               2.115276e+07
# EpiVacCorona, Sputnik V                                   6.916898e+06
# Johnson&Johnson                                           1.211108e+05
# Johnson&Johnson, Moderna, Pfizer/BioNTech                 6.317473e+07
# Moderna                                                   6.407565e+04
# Moderna, Oxford/AstraZeneca                               2.374880e+04
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech              1.247558e+06
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, S...        8.717221e+05
# Moderna, Pfizer/BioNTech                                  2.928883e+06
# Oxford/AstraZeneca                                        2.929786e+05
# Oxford/AstraZeneca, Pfizer/BioNTech                       3.974634e+06
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/...        4.854818e+06
# ...

# %%
    dataset["Vaccines"].hist()
# Out:
# <AxesSubplot:>

# %%
    dataset["Country"].hist()
# Out:
# <AxesSubplot:>

# %%
display(data[data["Vaccines"]=="Pfizer/BioNTech"][['Country','ISO Code','Date','Vaccines','Total Vaccinations','1st Dose','2nd Dose','Daily Vaccinations','Source Name']].sort_values(by="Total Vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_96e63f91_9777_11eb_98f7_00d8612af198row0_col4,#T_96e63f91_9777_11eb_98f7_00d8612af198row0_col5,#T_96e63f91_9777_11eb_98f7_00d8612af198row1_col7,#T_96e63f91_9777_11eb_98f7_00d8612af198row2_col6,#T_96e63f91_9777_11eb_98f7_00d8612af198row4_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_96e63f91_9777_11eb_98f7_00d8612af198row0_col6{
#             background-color:  #f13e33;
#             color:  #f1f1f1;
#         }#T_96e63f91_9777_11eb_98f7_00d8612af198row0_col7{
#             background-color:  #010104;
#             color:  #f1f1f1;
#         }#T_96e63f91_9777_11eb_98f7_00d8612af198row1_col4{
#             background-color:  #5728b7;
#             color:  #f1f1f1;
#         }#T_96e63f91_9777_11eb_98f7_00d8612af198row1_col5,#T_96e63f91_9777_11eb_98f7_00d8612af198row3_col7{
#             background-color:  #181850;
#             color:  #f1f1f1;
#         }#T_96e63f91_9777_11eb_98f7_00d8612af198row1_col6{
# ...

# %%
display(data[data["Vaccines"]=="Oxford/AstraZeneca"][['Country','ISO Code','Date','Vaccines','Total Vaccinations','1st Dose','2nd Dose','Daily Vaccinations','Source Name']].sort_values(by="Total Vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_9b98cd8c_9777_11eb_b63d_00d8612af198row0_col4,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row0_col5,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row0_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row1_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row2_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row3_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row4_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row5_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row6_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row7_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row8_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row9_col6,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row9_col7{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_9b98cd8c_9777_11eb_b63d_00d8612af198row0_col7,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row9_col4,#T_9b98cd8c_9777_11eb_b63d_00d8612af198row9_col5{
#             background-color:  #ffffff;
#             color:  #000000;
# ...

# %%
display(data[data["Vaccines"]=="Sputnik V"][['Country','ISO Code','Date','Vaccines','Total Vaccinations','1st Dose','2nd Dose','Daily Vaccinations','Source Name']].sort_values(by="Total Vaccinations", ascending= False).head(10).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# #T_96ecd8cb_9777_11eb_905a_00d8612af198row0_col4,#T_96ecd8cb_9777_11eb_905a_00d8612af198row0_col5,#T_96ecd8cb_9777_11eb_905a_00d8612af198row0_col6,#T_96ecd8cb_9777_11eb_905a_00d8612af198row5_col7{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_96ecd8cb_9777_11eb_905a_00d8612af198row0_col7,#T_96ecd8cb_9777_11eb_905a_00d8612af198row5_col6{
#             background-color:  #933285;
#             color:  #f1f1f1;
#         }#T_96ecd8cb_9777_11eb_905a_00d8612af198row1_col4{
#             background-color:  #232374;
#             color:  #f1f1f1;
#         }#T_96ecd8cb_9777_11eb_905a_00d8612af198row1_col5,#T_96ecd8cb_9777_11eb_905a_00d8612af198row2_col6{
#             background-color:  #352698;
#             color:  #f1f1f1;
#         }#T_96ecd8cb_9777_11eb_905a_00d8612af198row1_col6{
#             background-color:  #181850;
#             color:  #f1f1f1;
#         }#T_96ecd8cb_9777_11eb_905a_00d8612af198row1_col7{
# ...

# %%
display(data[['Country','Vaccines','Total Vaccinations']].groupby(['Country','Vaccines']).agg(["max",'mean',"min"]).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
# ...
